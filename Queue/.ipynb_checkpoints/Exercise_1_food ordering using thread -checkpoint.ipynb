# %% [markdown]
# ### Design a food ordering system where your python program will run two threads,
#
# ##### 1 : Place Order: This thread will be placing an order and inserting that into a queue. This thread places new order every 0.5 second. (hint: use time.sleep(0.5) function)
#
# ##### 2 : Serve Order: This thread will server the order. All you need to do is pop the order out of the queue and print it. This thread serves an order every 2 seconds. Also start this thread 1 second after place order thread is started.
#
# Pass following list as an argument to place order thread,
# orders = ['pizza','samosa','pasta','biryani','burger']

# %%
from collections import deque

class Queue:
    def __init__(self):
        self.buffer = deque()
        
    def enqueue(self, val):
        self.buffer.appendleft(val)
        
    def dequeue(self):
        if len(self.buffer) == 0:
            print("Queue is empty")
            return
        
        return self.buffer.pop()
    
    def isEmpty(self):
        return len(self.buffer) == 0
    
    def size(self):
        return len(self.buffer)

# %%
import time
import threading

foodOrdering = Queue()

def placeOrder(orders):
    for food in orders:
        print('placing order for :', food)
        foodOrdering.enqueue(food)
        time.sleep(0.5)
    
def serveOrder():
    time.sleep(1)
    while True:
        order = foodOrdering.dequeue()
        print("Your server is reday :", order )
        time.sleep(2)
    
orders = ['pizza','samosa','pasta','biryani','burger']
t1 = threading.Thread(target=placeOrder, args=(orders,))
t2 = threading.Thread(target=serveOrder)

t1.start()
t2.start()
# Out:
# placing order for : pizza
# placing order for : samosa
# Your server is reday : pizza
# placing order for : pasta
# placing order for : biryani
# placing order for : burger
# Your server is reday : samosa
# Your server is reday : pasta
# Your server is reday : biryani
# Your server is reday : burger
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
# Queue is empty
# Your server is reday : None
